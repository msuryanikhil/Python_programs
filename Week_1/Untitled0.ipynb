# %% [markdown]
# <a href="https://colab.research.google.com/github/msuryanikhil/Python_programs/blob/main/Week_1/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
print("5+8")
# Out:
# 5+8

# %%
print(5+8)
# Out:
# 13

# %%
print('%d surya ',5+7)
# Out:
# %d surya  12

# %%
a="ss"
print("%d",a)
# Out:
# %d ss

# %%
print(type(input("enter any to know the type of that: ")))
# Out:
# enter any to know the type of that: amni
# <class 'str'>

# %%
a=int(input("enter integer to store in variable a: "))
# Out:
# enter integer to store in variable a: 143

# %%
a
# Out:
# 143

# %%
b=float(input("enter float value to store in variable b: "))
# Out:
# enter float value to store in variable b: 7.9

# %%
b
# Out:
# 7.9

# %%
s=str(input("enter a string: "))
# Out:
# enter a string: surya

# %%
s
# Out:
# 'surya'

# %% [markdown]
# # arthemetic opertors in python
# 1. addition +
# 2. subtraction -
# 3. multiplication *
# 4. normal division /
# 5. floor division // gives integer quotient
# 6. modulo division % gives remainder
# 7. exponent ** it perform power

# %%
p= int(input("enter p value: "))
q= int(input("enter q value: "))
print("p+q:",p+q, ",p-q:",p-q, ",p*q:",p*q,",p/q:",p/q,",p//q:",p//q,",p%q(remainder):",p%q,",p**q:",p**q)
# Out:
# enter p value: 3
# enter q value: 1
# p+q: 4 ,p-q: 2 ,p*q: 3 ,p/q: 3.0 ,p//q: 3 ,p%q(remainder): 0 ,p**q: 3
