# %% [markdown]
# <a href="https://colab.research.google.com/github/msuryanikhil/Python_programs/blob/main/week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(3.2/2)
# Out:
# 1.6

# %%
print(1.8//3)
# Out:
# 0.0

# %%
print(1.8/3)
# Out:
# 0.6

# %%
print(-1.8/3)
# Out:
# -0.6

# %%
print(-1.8//3)
# Out:
# -1.0

# %%
print(2.0%2)
# Out:
# 0.0

# %%
x=3
y=3
L=[1,2,3]

print(x is y)
print(id(x))
print(id(y))
# Out:
# True
# 11645416
# 11645416

# %% [markdown]
# #write program to find greatest among 3 numbers

# %%
a=int(input("enter a value: "))
b=int(input("enter b value: "))
c=int(input("enter c value: "))

if(a>b and a>c):
  print(a,"is greatest")
elif(b>a and b>c):
  print(b,"is greatest")
else:
  print(c,"is greatest")
# Out:
# enter a value: 4
# enter b value: 3
# enter c value: 7
# 7 is greatest

# %% [markdown]
# #print FIZZ if a number is divisible by 3, print BUZZ if a number is divisible by 5, print FIZZBUZZ if it is divisible by both 3 and 5

# %%
a=int(input("enter a value: "))
if (a%3==0):
  print("FIZZ")
elif(a%5==0):
  print("BUZZ")
elif (a%3==0 and a%5==0):
  print("FIZZBUZZ")
# Out:
# enter a value: 24
# FIZZ

# %% [markdown]
# # print FIZZ if a number is divisible by only 3, print BUZZ if a number is divisible by only 5, print FIZZBUZZ if it is divisible by both 3 and 5

# %%
a=int(input("enter a value: "))
if (a%3==0 and a%5!=0):
  print("FIZZ")
elif(a%5==0 and a%3!=0):
  print("BUZZ")
elif (a%3==0 and a%5==0):
  print("FIZZBUZZ")
else:
  print()
# Out:
# enter a value: 22

# %% [markdown]
# #Read 2 complex numbers and print addition & multiplications

# %%
a=complex(2,3)
print(a)
# Out:
# (2+3j)

# %%
a=complex(input("enter 1st complex number: "))
b=complex(input("enter 2nd complex number: "))
print(a+b)
print(a*b)
# Out:
# enter 1st complex number: 2+3j
# enter 2nd complex number: 4+5j
# (6+8j)
# (-7+22j)

# %% [markdown]
# #Program that swaps 2 variables without using temp variable

# %%
a=int(input("enter a value: "))
b=int(input("enter b value: "))
print(a,b)
a,b=b,a
print(a,b)
# Out:
# enter a value: 2
# enter b value: 4
# 2 4
# 4 2
